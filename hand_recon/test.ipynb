# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('1.jpg')
img.shape[0]
# Out:
# 1260

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('1.jpg')
plt.imshow(img)

# %%
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from slope import find_m, getValue
img = mpimg.imread('M_test.png')
plt.imshow(img)
print(getValue(175,250,img))
# Out:
# x_shift:  6
# round(img.shape[0]/20):  18
# width:  79
# 75

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("res/hand_1.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
print(img.shape)
ret, img = cv2.threshold(img, 80, 255, cv2.THRESH_BINARY)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# (568, 320)

# %%
import cv2
import mediapipe as mp
import time
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = cv2.imread("res/hand_1.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
blur_img = cv2.medianBlur(img,5) 
img = cv2.adaptiveThreshold(blur_img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4360/3076098816.py in <module>
#       9 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      10 blur_img = cv2.medianBlur(img,5)
# ---> 11 img = cv2.adaptiveThreshold(blur_img,255,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,2)
#      12 plt.imshow(img)
#
# error: OpenCV(4.5.5) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\thresh.cpp:1674: error: (-215:Assertion failed) src.type() == CV_8UC1 in function 'cv::adaptiveThreshold'

# %%
m = -28.0 # 6是參數, 視實際拍攝圖片決定
total = 137.89473684210526
print("total", total)
cun = total * 1/5
guan = total * 1/2
chi = total * 33/40
print("cun", cun)
print("guan", guan)
print("chi", chi)
print("m",m)

#cunx = round(cun / ((m*m+1)**(0.5)))
#cuny = round(m * cunx)
guanx = guan / ((m*m+1)**(0.5))
guany = round(m * guanx)
#chix = round(chi / ((m*m+1)**(0.5)))
#chiy = round(m * chix)
#print("cuny", cuny)
print("guany", guany)
#print("chiy", chiy)
# Out:
# total 137.89473684210526
# cun 27.57894736842105
# guan 68.94736842105263
# chi 113.76315789473684
# m -28.0
# guany -56
